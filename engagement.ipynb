# %%
d <- read.csv('output.csv')

# %%
library("car")

# %%
scatterplotMatrix(d[c(0, 1, 2, 3, 4, 6, 7)])
# Out:
# Warning message in smoother(x, y, col = col[2], log.x = FALSE, log.y = FALSE, spread = spread, :
# “could not fit negative part of the spread”Warning message in smoother(x, y, col = col[2], log.x = FALSE, log.y = FALSE, spread = spread, :
# “could not fit smooth”Warning message in smoother(x, y, col = col[2], log.x = FALSE, log.y = FALSE, spread = spread, :
# “could not fit smooth”Warning message in smoother(x, y, col = col[2], log.x = FALSE, log.y = FALSE, spread = spread, :
# “could not fit smooth”Warning message in smoother(x, y, col = col[2], log.x = FALSE, log.y = FALSE, spread = spread, :
# “could not fit smooth”Warning message in smoother(x, y, col = col[2], log.x = FALSE, log.y = FALSE, spread = spread, :
# “could not fit negative part of the spread”Warning message in smoother(x, y, col = col[2], log.x = FALSE, log.y = FALSE, spread = spread, :
# ...

# %%
barplot(table(d$eng))
# Out:
# plot without title

# %%
table(d$eng)
# Out:
#                                   As needed - Less than 10 hrs/week
#                               425                               151
#          Full-time - 30+ hrs/week        Part-time - 10-30 hrs/week
#                                58                               231

# %%
table(d$weeks)
# Out:
#                         1 to 3 months      3 to 6 months  Less than 1 month
#                425                 63                 44                 65
#   Less than 1 week More than 6 months
#                153                115

# %%
tapply(d$inte, d$eng, mean)
# Out:
#                                   As needed - Less than 10 hrs/week
#                      0.0023764706                      0.0005298013
#          Full-time - 30+ hrs/week        Part-time - 10-30 hrs/week
#                      0.0029310345                      0.0039393939

# %%
tapply(d$char, d$eng, mean)
# Out:
#                                   As needed - Less than 10 hrs/week
#                          5046.129                          5733.713
#          Full-time - 30+ hrs/week        Part-time - 10-30 hrs/week
#                         11082.477                          6245.924

# %%
tapply(d$cand, d$eng, mean)
# Out:
#                                   As needed - Less than 10 hrs/week
#                          13.89176                          15.01987
#          Full-time - 30+ hrs/week        Part-time - 10-30 hrs/week
#                          18.00000                          15.29870
