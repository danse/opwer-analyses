# %%
d <- read.csv('output-as_needed.csv')

# %%
table(d$eng)
# Out:
# As needed - Less than 10 hrs/week
#                               177

# %%
table(d$weeks)
# Out:
#      1 to 3 months      3 to 6 months  Less than 1 month   Less than 1 week
#                 24                 18                 46                 63
# More than 6 months
#                 26

# %% [markdown]
# This is good news! All results have engagement and duration specified and there is a significant amount of them specifying long term duration

# %%
hist(d$aver)
# Out:
# Plot with title “Histogram of d$aver”

# %%
hist(d$cand)
# Out:
# Plot with title “Histogram of d$cand”

# %% [markdown]
# Good news? Most applicants focus only on some job offers

# %%
scatterplotMatrix(d[c(1, 5)])
# Out:
# plot without title

# %% [markdown]
# High average jobs with few applicants are the most interesting

# %%
hist(d$aver/d$cand)
# Out:
# Plot with title “Histogram of d$aver/d$cand”

# %%
library('car')

# %%
scatterplotMatrix(d[c(1, 2)])
# Out:
# plot without title

# %%
scatterplotMatrix(d[c(1, 2, 4, 5)])
# Out:
# Warning message in smoother(x, y, col = col[2], log.x = FALSE, log.y = FALSE, spread = spread, :
# “could not fit smooth”
# plot without title

# %%
scatterplotMatrix(d[c(1, 2, 3, 4, 5, 7)])
# Out:
# Warning message in smoother(x, y, col = col[2], log.x = FALSE, log.y = FALSE, spread = spread, :
# “could not fit smooth”Warning message in smoother(x, y, col = col[2], log.x = FALSE, log.y = FALSE, spread = spread, :
# “could not fit smooth”
# plot without title
