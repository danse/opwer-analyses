# %%
d <- read.csv('output-part_time.csv')

# %% [markdown]
# This analysis was done on part time jobs on all categories

# %%
table(d$eng)
# Out:
# Part-time - 10-30 hrs/week
#                        170

# %%
table(d$weeks)
# Out:
#      1 to 3 months      3 to 6 months  Less than 1 month   Less than 1 week
#                 20                 18                 23                 61
# More than 6 months
#                 48

# %%
hist(d$cand)
# Out:
# Plot with title “Histogram of d$cand”

# %%
scatterplotMatrix(d[c(0, 1, 2, 3, 4, 7)])
# Out:
# Warning message in smoother(x, y, col = col[2], log.x = FALSE, log.y = FALSE, spread = spread, :
# “could not fit negative part of the spread”Warning message in smoother(x, y, col = col[2], log.x = FALSE, log.y = FALSE, spread = spread, :
# “could not fit negative part of the spread”
# plot without title
